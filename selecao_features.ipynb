# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.feature_selection import RFE, RFECV, SelectFromModel
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, f1_score

# %% [markdown]
# ### Carregar e visualizar os dados - Regressao

# %%
# Carregar os daddos - Regressao
df = pd.read_csv('./datasets/dataset_colesterol.csv')

# %%
# Visualizar Estrutura
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  1000 non-null   int64
#  1   Grupo Sanguíneo     1000 non-null   object
#  2   Fumante             1000 non-null   object
#  3   Nível de Atividade  1000 non-null   object
#  4   Idade               1000 non-null   int64
#  5   Peso                1000 non-null   float64
#  6   Altura              1000 non-null   int64
#  7   Colesterol          1000 non-null   float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 62.6+ KB

# %%
# Visualizar Dataframe
df.head(10)
# Out:
#    Id Grupo Sanguíneo Fumante Nível de Atividade  Idade   Peso  Altura  \
# 0   1               B     Sim              Baixo     33   85.1     186
# 1   2               A     Não           Moderado     68  105.0     184
# 2   3               O     Não               Alto     25   64.8     180
# 3   4               A     Não               Alto     43  120.2     167
# 4   5              AB     Não              Baixo     79   88.5     175
# 5   6               B     Não              Baixo     68   66.8     170
# 6   7               A     Sim              Baixo     60  117.3     181
# 7   8               O     Sim           Moderado     35   86.9     174
# 8   9               O     Não              Baixo     62   81.3     166
# 9  10               B     Sim               Alto     44   32.7     165
#
#    Colesterol
# 0      199.63
# 1      236.98
# 2      161.79
# 3      336.24
# 4      226.23
# 5      185.31
# 6      289.33
# 7      216.48
# 8      235.30
# 9       97.79

# %%
# Ajustar Dataframe

df.drop('Id', axis=1, inplace=True)

# Aplicar OneHotEncoding nas variaveis categoricas
df = pd.get_dummies(df, columns=['Grupo Sanguíneo', 'Fumante', 'Nível de Atividade'])

# %%
# DataFrame atualizado 

df
# Out:
#      Idade   Peso  Altura  Colesterol  Grupo Sanguíneo_A  Grupo Sanguíneo_AB  \
# 0       33   85.1     186      199.63                  0                   0
# 1       68  105.0     184      236.98                  1                   0
# 2       25   64.8     180      161.79                  0                   0
# 3       43  120.2     167      336.24                  1                   0
# 4       79   88.5     175      226.23                  0                   1
# ..     ...    ...     ...         ...                ...                 ...
# 995     31   68.1     166      206.81                  0                   1
# 996     51   47.7     170      128.03                  0                   0
# 997     39   85.5     176      211.14                  0                   1
# 998     61   91.2     161      284.53                  0                   1
# 999     45   82.4     163      237.45                  1                   0
#
#      Grupo Sanguíneo_B  Grupo Sanguíneo_O  Fumante_Não  Fumante_Sim  \
# 0                    1                  0            0            1
# 1                    0                  0            1            0
# 2                    0                  1            1            0
# 3                    0                  0            1            0
# 4                    0                  0            1            0
# ..                 ...                ...          ...          ...
# 995                  0                  0            0            1
# 996                  0                  1            1            0
# 997                  0                  0            1            0
# 998                  0                  0            0            1
# 999                  0                  0            1            0
#
#      Nível de Atividade_Alto  Nível de Atividade_Baixo  \
# 0                          0                         1
# 1                          0                         0
# 2                          1                         0
# 3                          1                         0
# 4                          0                         1
# ..                       ...                       ...
# 995                        0                         0
# 996                        1                         0
# 997                        0                         1
# 998                        0                         1
# 999                        0                         1
#
#      Nível de Atividade_Moderado
# 0                              0
# 1                              1
# 2                              0
# 3                              0
# 4                              0
# ..                           ...
# 995                            1
# 996                            0
# 997                            0
# 998                            0
# 999                            0
#
# [1000 rows x 13 columns]

# %% [markdown]
# ### Treinar modelo de regressao linear multipla com RFE

# %%
X = df.drop('Colesterol', axis=1)
y = df['Colesterol']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 X = df.drop('Colesterol', axis=1)
#       2 y = df['Colesterol']
#
# NameError: name 'df' is not defined

# %%
# Separar Treino e Teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=51)

# %%
# Treinar o modelo com RFE
# RFE (Recursive Feature Elimination)
# Uso um estimador e defino uma quantidade de feature (dois hiperparametros)
# O RFE faz interaçoes iniciando com todas as features e eliminando a cada interaçao ate atingir a quantidade definida
# Elimina caracteristicas/features menos importantes
rfe_method = RFE(estimator=LinearRegression(), n_features_to_select=2)
rfe_method.fit(X_train, y_train)
# Out:
# RFE(estimator=LinearRegression(), n_features_to_select=2)

# %%
# Quais features foram selecionadas
X_train.columns[(rfe_method.get_support())]
# Out:
# Index(['Peso', 'Altura'], dtype='object')

# %%
# Ranking de Features

def mostrar_ranking(metodo_fs, x_train):

    #Obter o Ranking de Features
    ranking = rfe_method.ranking_

    #Obter os nomes das features
    nomes_features = X_train.columns.to_list()

    # Crie um Dataframe com os rankings e os nomes das features
    df_ranking = pd.DataFrame({'Feature': nomes_features, 'Ranking': ranking})

    #Ordene o Dataframe pelo Ranking
    df_ranking = df_ranking.sort_values(by='Ranking')

    #Exibir Ranking
    print(df_ranking)

# %%
# Ranking de Features de RFE Regressao
mostrar_ranking(rfe_method, X_train)
# Out:
#                         Feature  Ranking
# 1                          Peso        1
# 2                        Altura        1
# 9       Nível de Atividade_Alto        2
# 7                   Fumante_Não        3
# 4            Grupo Sanguíneo_AB        4
# 8                   Fumante_Sim        5
# 5             Grupo Sanguíneo_B        6
# 3             Grupo Sanguíneo_A        7
# 11  Nível de Atividade_Moderado        8
# 10     Nível de Atividade_Baixo        9
# 6             Grupo Sanguíneo_O       10
# 0                         Idade       11

# %%
# Funçao para avaliar performance
def performance_regressao(modelo, X_test, y_test):
    #Faz a prediçao com o modelo no conjunto de testes
    y_pred = modelo.predict(X_test)
    # Avaliar desempenho
    return mean_squared_error(y_test, y_pred, squared=False)

# %%
performance_regressao(rfe_method, X_test, y_test)
# Out:
# /home/perry/.local/share/virtualenvs/ALGORITMOS_SUPERVISIONADOS-vK7GRsgu/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 9.07534344694708

# %% [markdown]
# ### Treinar modelo sem RFE

# %%
# Treinar Modelo de Regressao sem RFE
model_reg = LinearRegression()
model_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
performance_regressao(model_reg, X_test, y_test)
# Out:
# /home/perry/.local/share/virtualenvs/ALGORITMOS_SUPERVISIONADOS-vK7GRsgu/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 9.017674671581466

# %% [markdown]
# ### Treinar Modelo de Regressao Linear com RFECV

# %%
rfe_method_cv = RFECV(estimator=LinearRegression(), min_features_to_select=6, cv=5)
rfe_method_cv.fit(X_train, y_train)
# Out:
# RFECV(cv=5, estimator=LinearRegression(), min_features_to_select=6)

# %%
performance_regressao(rfe_method_cv, X_test, y_test)
# Out:
# /home/perry/.local/share/virtualenvs/ALGORITMOS_SUPERVISIONADOS-vK7GRsgu/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 9.02288233120335

# %%
X_test.columns[(rfe_method_cv.get_support())]
# Out:
# Index(['Peso', 'Altura', 'Grupo Sanguíneo_A', 'Grupo Sanguíneo_AB',
#        'Grupo Sanguíneo_B', 'Fumante_Não', 'Fumante_Sim',
#        'Nível de Atividade_Alto', 'Nível de Atividade_Baixo',
#        'Nível de Atividade_Moderado'],
#       dtype='object')

# %%
rfe_method_cv.n_features_
# Out:
# 10

# %% [markdown]
# ### Treinar modelo de regressao com SelectFromModel

# %%
sfm_method = SelectFromModel(estimator=model_reg, max_features=2, threshold=0.01)
sfm_method.fit(X_train, y_train)
# Out:
# SelectFromModel(estimator=LinearRegression(), max_features=2, threshold=0.01)

# %%
#Quais features foram selecionadas
X_test.columns[(sfm_method.get_support())]
# Out:
# Index(['Peso', 'Altura'], dtype='object')

# %%
# Treinar modelo com as features selecionadas
X_train_ajustado_reg = sfm_method.transform(X_train)
X_test_ajustado_reg = sfm_method.transform(X_test)
model_reg.fit(X_train_ajustado_reg, y_train)
# Out:
# LinearRegression()

# %%
# Perfoarmance do Modelo com SelectFromModel
performance_regressao(model_reg, X_test_ajustado_reg, y_test )
# Out:
# /home/perry/.local/share/virtualenvs/ALGORITMOS_SUPERVISIONADOS-vK7GRsgu/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 9.07534344694708

# %% [markdown]
# ### Carregar e preparar dados - Classificaçao

# %%
# Carregar o dataset
df2 = pd.read_csv('./datasets/fruit_quality.csv')

# %%
# Visualizar estrutura 
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   int64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4000 non-null   float64
#  8   Quality      4000 non-null   object
# dtypes: float64(7), int64(1), object(1)
# memory usage: 281.4+ KB

# %%
# Visualizar DF
df2.head(10)
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0     0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1     1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2     2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3     3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# 5     5 -3.425400 -1.409082  -1.913511    -0.555775  -3.853071  1.914616
# 6     6  1.331606  1.635956   0.875974    -1.677798   3.106344 -1.847417
# 7     7 -1.995462 -0.428958   1.530644    -0.742972   0.158834  0.974438
# 8     8 -3.867632 -3.734514   0.986429    -1.207655   2.292873  4.080921
# 9     9 -0.727983 -0.442820  -4.092223     0.597513   0.393714  1.620857
#
#     Acidity Quality
# 0 -0.491590    good
# 1 -0.722809    good
# 2  2.621636     bad
# 3  0.790723    good
# 4  0.501984    good
# 5 -2.981523     bad
# 6  2.414171    good
# 7 -1.470125    good
# 8 -4.871905     bad
# 9  2.185608     bad

# %%
# Ajustar Dataframe

# Remover a coluna 'A_id'
df2.drop('A_id', axis=1, inplace=True)

df2['Quality'] = (df2['Quality'] == 'good').astype(int)

df2
# Out:
#           Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0    -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1    -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2    -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3    -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4     1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...        ...       ...        ...          ...        ...       ...
# 3995  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#        Acidity  Quality
# 0    -0.491590        1
# 1    -0.722809        1
# 2     2.621636        0
# 3     0.790723        1
# 4     0.501984        1
# ...        ...      ...
# 3995  0.137784        0
# 3996  1.854235        1
# 3997 -1.334611        0
# 3998 -2.229720        1
# 3999  1.599796        1
#
# [4000 rows x 8 columns]

# %% [markdown]
# ### Treinar modelo de regressao logistica com RFE

# %%
X = df2.drop('Quality', axis=1)
y = df2['Quality']

# %%
# Separar Treino e Teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=51)

# %%
# Treinar o modelo com RFE
# RFE (Recursive Feature Elimination)
# Uso um estimador e defino uma quantidade de feature (dois hiperparametros)
# O RFE faz interaçoes iniciando com todas as features e eliminando a cada interaçao ate atingir a quantidade definida
# Elimina caracteristicas/features menos importantes
rfe_method = RFE(estimator=LogisticRegression(), n_features_to_select=2)
rfe_method.fit(X_train, y_train)
# Out:
# RFE(estimator=LogisticRegression(), n_features_to_select=2)

# %%
# Quais features foram selecionadas
X_train.columns[(rfe_method.get_support())]
# Out:
# Index(['Size', 'Sweetness'], dtype='object')

# %%
# Ranking de Features

def mostrar_ranking(metodo_fs, x_train):

    #Obter o Ranking de Features
    ranking = rfe_method.ranking_

    #Obter os nomes das features
    nomes_features = X_train.columns.to_list()

    # Crie um Dataframe com os rankings e os nomes das features
    df_ranking = pd.DataFrame({'Feature': nomes_features, 'Ranking': ranking})

    #Ordene o Dataframe pelo Ranking
    df_ranking = df_ranking.sort_values(by='Ranking')

    #Exibir Ranking
    print(df_ranking)
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.

# %%
# Ranking de Features de RFE Regressao
mostrar_ranking(rfe_method, X_train)
# Out:
#        Feature  Ranking
# 0         Size        1
# 2    Sweetness        1
# 4    Juiciness        2
# 1       Weight        3
# 6      Acidity        4
# 5     Ripeness        5
# 3  Crunchiness        6

# %%
# Funçao para avaliar performance
def performance_classificacao(modelo, X_test, y_test):
    #Faz a prediçao com o modelo no conjunto de testes
    y_pred = modelo.predict(X_test)
    # Avaliar desempenho
    return f1_score(y_test, y_pred)

# %%
performance_classificacao(rfe_method, X_test, y_test)
# Out:
# 0.697171381031614

# %% [markdown]
# ### Treinar Modelo sem RFE

# %%
# Treinar modelo sem RFE
model_lr = LogisticRegression()
model_lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Validar Performance 
performance_classificacao(model_lr, X_test, y_test)
# Out:
# 0.7787903893951947

# %% [markdown]
# ### Treinar Modelo de Regressao Logistica com RFECV

# %%
rfe_method_cv = RFECV(estimator=LogisticRegression(), min_features_to_select=6, cv=5, scoring='f1_weighted')
rfe_method_cv.fit(X_train, y_train)
# Out:
# RFECV(cv=5, estimator=LogisticRegression(), min_features_to_select=6,
#       scoring='f1_weighted')

# %%
performance_regressao(rfe_method_cv, X_test, y_test)
# Out:
# /home/perry/.local/share/virtualenvs/ALGORITMOS_SUPERVISIONADOS-vK7GRsgu/lib/python3.11/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 0.473462423711393

# %%
X_test.columns[(rfe_method_cv.get_support())]
# Out:
# Index(['Size', 'Weight', 'Sweetness', 'Juiciness', 'Ripeness', 'Acidity'], dtype='object')

# %%
rfe_method_cv.n_features_
# Out:
# 6

# %% [markdown]
# ### Treinar modelo de regressao logistica com SelectFromModel

# %%
sfm_method = SelectFromModel(estimator=model_lr, max_features=2)
sfm_method.fit(X_train, y_train)
# Out:
# SelectFromModel(estimator=LogisticRegression(), max_features=2)

# %%
#Quais features foram selecionadas
X_test.columns[(sfm_method.get_support())]
# Out:
# Index(['Size', 'Sweetness'], dtype='object')

# %%
# Treinar modelo com as features selecionadas
X_train_ajustado_class = sfm_method.transform(X_train)
X_test_ajustado_class = sfm_method.transform(X_test)
model_lr.fit(X_train_ajustado_class, y_train)
# Out:
# LogisticRegression()

# %%
# Perfoarmance do Modelo com SelectFromModel
performance_classificacao(model_lr, X_test_ajustado_class, y_test )
# Out:
# 0.697171381031614
